# %%
# !pip install yfinance
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn
# Out:
# Requirement already satisfied: yfinance in c:\users\frodo\anaconda3\lib\site-packages (0.2.31)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\frodo\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\frodo\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: requests>=2.31 in c:\users\frodo\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\frodo\anaconda3\lib\site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\frodo\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: html5lib>=1.1 in c:\users\frodo\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\frodo\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\frodo\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\frodo\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\frodo\anaconda3\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\frodo\anaconda3\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\frodo\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\frodo\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\frodo\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\frodo\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\frodo\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\frodo\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\frodo\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\frodo\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: pandas in c:\users\frodo\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\frodo\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\frodo\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\frodo\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\frodo\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\frodo\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\frodo\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\frodo\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\frodo\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\frodo\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\frodo\anaconda3\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\frodo\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\frodo\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\frodo\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\frodo\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: six>=1.5 in c:\users\frodo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\frodo\anaconda3\lib\site-packages (1.2.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\frodo\anaconda3\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\frodo\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\frodo\anaconda3\lib\site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\frodo\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# %%
data = yf.download('AAPL', start='2020-01-01', end='2023-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df = data['Close'].values.reshape(-1, 1)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
df = scaler.fit_transform(df)

# %%
training_size = int(len(df) * 0.75)
train_data, test_data = df[0:training_size, :], df[training_size:len(df), :]

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(time_step, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=150, batch_size=64, verbose=1)
# Out:
# Epoch 1/150
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0015 - val_loss: 0.0055
# Epoch 2/150
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0018 - val_loss: 0.0050
# Epoch 3/150
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 4/150
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 5/150
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 6/150
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 7/150
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 8/150
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 9/150
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 10/150
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 11/150
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 12/150
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 13/150
# 8/8 [==============================] - 1s 108ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 14/150
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0012 - val_loss: 0.0027
# Epoch 15/150
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 16/150
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 17/150
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 18/150
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 19/150
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 20/150
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0011 - val_loss: 0.0028
# Epoch 21/150
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 22/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 23/150
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 24/150
# 8/8 [==============================] - 1s 108ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 25/150
# 8/8 [==============================] - 1s 117ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 26/150
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 27/150
# 8/8 [==============================] - 1s 114ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 28/150
# 8/8 [==============================] - 1s 115ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 29/150
# 8/8 [==============================] - 1s 110ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 30/150
# 8/8 [==============================] - 1s 111ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 31/150
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 32/150
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 33/150
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 34/150
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 35/150
# 8/8 [==============================] - 1s 105ms/step - loss: 9.9027e-04 - val_loss: 0.0016
# Epoch 36/150
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 37/150
# 8/8 [==============================] - 1s 101ms/step - loss: 9.9083e-04 - val_loss: 0.0015
# Epoch 38/150
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0011 - val_loss: 0.0033
# Epoch 39/150
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 40/150
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 41/150
# 8/8 [==============================] - 1s 101ms/step - loss: 9.6907e-04 - val_loss: 0.0018
# Epoch 42/150
# 8/8 [==============================] - 1s 102ms/step - loss: 9.7924e-04 - val_loss: 0.0013
# Epoch 43/150
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 44/150
# 8/8 [==============================] - 1s 100ms/step - loss: 9.3073e-04 - val_loss: 0.0014
# Epoch 45/150
# 8/8 [==============================] - 1s 102ms/step - loss: 9.5978e-04 - val_loss: 0.0016
# Epoch 46/150
# 8/8 [==============================] - 1s 102ms/step - loss: 8.8632e-04 - val_loss: 0.0014
# Epoch 47/150
# 8/8 [==============================] - 1s 103ms/step - loss: 8.8558e-04 - val_loss: 0.0014
# Epoch 48/150
# 8/8 [==============================] - 1s 101ms/step - loss: 9.3089e-04 - val_loss: 0.0014
# Epoch 49/150
# 8/8 [==============================] - 1s 101ms/step - loss: 9.7136e-04 - val_loss: 0.0024
# Epoch 50/150
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 51/150
# 8/8 [==============================] - 1s 107ms/step - loss: 9.8111e-04 - val_loss: 0.0013
# Epoch 52/150
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 53/150
# 8/8 [==============================] - 1s 102ms/step - loss: 0.0011 - val_loss: 0.0025
# Epoch 54/150
# 8/8 [==============================] - 1s 107ms/step - loss: 9.2177e-04 - val_loss: 0.0014
# Epoch 55/150
# 8/8 [==============================] - 1s 102ms/step - loss: 8.6315e-04 - val_loss: 0.0013
# Epoch 56/150
# 8/8 [==============================] - 1s 99ms/step - loss: 8.2565e-04 - val_loss: 0.0015
# Epoch 57/150
# 8/8 [==============================] - 1s 104ms/step - loss: 8.1781e-04 - val_loss: 0.0012
# Epoch 58/150
# 8/8 [==============================] - 1s 111ms/step - loss: 8.0951e-04 - val_loss: 0.0012
# Epoch 59/150
# 8/8 [==============================] - 1s 110ms/step - loss: 8.3914e-04 - val_loss: 0.0012
# Epoch 60/150
# 8/8 [==============================] - 1s 106ms/step - loss: 8.4915e-04 - val_loss: 0.0014
# Epoch 61/150
# 8/8 [==============================] - 1s 108ms/step - loss: 8.6497e-04 - val_loss: 0.0021
# Epoch 62/150
# 8/8 [==============================] - 1s 107ms/step - loss: 9.5336e-04 - val_loss: 0.0012
# Epoch 63/150
# 8/8 [==============================] - 1s 109ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 64/150
# 8/8 [==============================] - 1s 109ms/step - loss: 9.1854e-04 - val_loss: 0.0017
# Epoch 65/150
# 8/8 [==============================] - 1s 109ms/step - loss: 8.7640e-04 - val_loss: 0.0014
# Epoch 66/150
# 8/8 [==============================] - 1s 107ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 67/150
# 8/8 [==============================] - 1s 107ms/step - loss: 8.8844e-04 - val_loss: 0.0019
# Epoch 68/150
# 8/8 [==============================] - 1s 107ms/step - loss: 8.8947e-04 - val_loss: 0.0017
# Epoch 69/150
# 8/8 [==============================] - 1s 109ms/step - loss: 8.5438e-04 - val_loss: 0.0011
# Epoch 70/150
# 8/8 [==============================] - 1s 109ms/step - loss: 7.6644e-04 - val_loss: 0.0011
# Epoch 71/150
# 8/8 [==============================] - 1s 110ms/step - loss: 8.1009e-04 - val_loss: 0.0011
# Epoch 72/150
# 8/8 [==============================] - 1s 107ms/step - loss: 7.8009e-04 - val_loss: 0.0012
# Epoch 73/150
# 8/8 [==============================] - 1s 107ms/step - loss: 7.1508e-04 - val_loss: 0.0012
# Epoch 74/150
# 8/8 [==============================] - 1s 108ms/step - loss: 7.6196e-04 - val_loss: 0.0012
# Epoch 75/150
# 8/8 [==============================] - 1s 111ms/step - loss: 9.3166e-04 - val_loss: 0.0019
# Epoch 76/150
# 8/8 [==============================] - 1s 108ms/step - loss: 9.0623e-04 - val_loss: 0.0021
# Epoch 77/150
# 8/8 [==============================] - 1s 108ms/step - loss: 7.7743e-04 - val_loss: 0.0012
# Epoch 78/150
# 8/8 [==============================] - 1s 106ms/step - loss: 6.7656e-04 - val_loss: 0.0012
# Epoch 79/150
# 8/8 [==============================] - 1s 113ms/step - loss: 7.4421e-04 - val_loss: 0.0012
# Epoch 80/150
# 8/8 [==============================] - 1s 109ms/step - loss: 6.9636e-04 - val_loss: 0.0013
# Epoch 81/150
# 8/8 [==============================] - 1s 108ms/step - loss: 6.8917e-04 - val_loss: 0.0011
# Epoch 82/150
# 8/8 [==============================] - 1s 109ms/step - loss: 8.6371e-04 - val_loss: 0.0020
# Epoch 83/150
# 8/8 [==============================] - 1s 108ms/step - loss: 8.1774e-04 - val_loss: 0.0010
# Epoch 84/150
# 8/8 [==============================] - 1s 109ms/step - loss: 8.1908e-04 - val_loss: 0.0011
# Epoch 85/150
# 8/8 [==============================] - 1s 109ms/step - loss: 6.6953e-04 - val_loss: 0.0016
# Epoch 86/150
# 8/8 [==============================] - 1s 108ms/step - loss: 6.8079e-04 - val_loss: 0.0012
# Epoch 87/150
# 8/8 [==============================] - 1s 113ms/step - loss: 6.5719e-04 - val_loss: 0.0011
# Epoch 88/150
# 8/8 [==============================] - 1s 108ms/step - loss: 6.4076e-04 - val_loss: 0.0012
# Epoch 89/150
# 8/8 [==============================] - 1s 109ms/step - loss: 6.2316e-04 - val_loss: 0.0013
# Epoch 90/150
# 8/8 [==============================] - 1s 107ms/step - loss: 6.5579e-04 - val_loss: 0.0012
# Epoch 91/150
# 8/8 [==============================] - 1s 150ms/step - loss: 7.6082e-04 - val_loss: 0.0012
# Epoch 92/150
# 8/8 [==============================] - 1s 133ms/step - loss: 6.4172e-04 - val_loss: 0.0012
# Epoch 93/150
# 8/8 [==============================] - 1s 107ms/step - loss: 6.1880e-04 - val_loss: 0.0019
# Epoch 94/150
# 8/8 [==============================] - 1s 109ms/step - loss: 6.7095e-04 - val_loss: 0.0015
# Epoch 95/150
# 8/8 [==============================] - 1s 108ms/step - loss: 6.4189e-04 - val_loss: 0.0011
# Epoch 96/150
# 8/8 [==============================] - 1s 109ms/step - loss: 7.2429e-04 - val_loss: 9.8486e-04
# Epoch 97/150
# 8/8 [==============================] - 1s 108ms/step - loss: 7.0657e-04 - val_loss: 0.0015
# Epoch 98/150
# 8/8 [==============================] - 1s 108ms/step - loss: 7.1923e-04 - val_loss: 9.6905e-04
# Epoch 99/150
# 8/8 [==============================] - 1s 109ms/step - loss: 7.5554e-04 - val_loss: 0.0014
# Epoch 100/150
# 8/8 [==============================] - 1s 108ms/step - loss: 6.0464e-04 - val_loss: 9.5842e-04
# Epoch 101/150
# 8/8 [==============================] - 1s 106ms/step - loss: 7.0573e-04 - val_loss: 0.0012
# Epoch 102/150
# 8/8 [==============================] - 1s 106ms/step - loss: 6.2563e-04 - val_loss: 0.0012
# Epoch 103/150
# 8/8 [==============================] - 1s 106ms/step - loss: 6.3040e-04 - val_loss: 0.0013
# Epoch 104/150
# 8/8 [==============================] - 1s 108ms/step - loss: 6.4285e-04 - val_loss: 9.6537e-04
# Epoch 105/150
# 8/8 [==============================] - 1s 109ms/step - loss: 7.2957e-04 - val_loss: 0.0011
# Epoch 106/150
# 8/8 [==============================] - 1s 111ms/step - loss: 6.6669e-04 - val_loss: 0.0013
# Epoch 107/150
# 8/8 [==============================] - 1s 110ms/step - loss: 6.9117e-04 - val_loss: 9.4191e-04
# Epoch 108/150
# 8/8 [==============================] - 1s 110ms/step - loss: 5.8042e-04 - val_loss: 0.0013
# Epoch 109/150
# 8/8 [==============================] - 1s 108ms/step - loss: 6.4181e-04 - val_loss: 9.6147e-04
# Epoch 110/150
# 8/8 [==============================] - 1s 106ms/step - loss: 7.9766e-04 - val_loss: 9.4371e-04
# Epoch 111/150
# 8/8 [==============================] - 1s 107ms/step - loss: 7.3403e-04 - val_loss: 0.0017
# Epoch 112/150
# 8/8 [==============================] - 1s 108ms/step - loss: 7.0857e-04 - val_loss: 9.1849e-04
# Epoch 113/150
# 8/8 [==============================] - 1s 107ms/step - loss: 6.0811e-04 - val_loss: 0.0011
# Epoch 114/150
# 8/8 [==============================] - 1s 110ms/step - loss: 5.8848e-04 - val_loss: 0.0012
# Epoch 115/150
# 8/8 [==============================] - 1s 107ms/step - loss: 5.4096e-04 - val_loss: 0.0010
# Epoch 116/150
# 8/8 [==============================] - 1s 109ms/step - loss: 5.3348e-04 - val_loss: 9.2531e-04
# Epoch 117/150
# 8/8 [==============================] - 1s 109ms/step - loss: 5.7330e-04 - val_loss: 9.0795e-04
# Epoch 118/150
# 8/8 [==============================] - 1s 109ms/step - loss: 5.8474e-04 - val_loss: 0.0014
# Epoch 119/150
# 8/8 [==============================] - 1s 106ms/step - loss: 7.9950e-04 - val_loss: 0.0015
# Epoch 120/150
# 8/8 [==============================] - 1s 108ms/step - loss: 6.6343e-04 - val_loss: 9.0226e-04
# Epoch 121/150
# 8/8 [==============================] - 1s 109ms/step - loss: 6.8482e-04 - val_loss: 0.0012
# Epoch 122/150
# 8/8 [==============================] - 1s 108ms/step - loss: 5.6128e-04 - val_loss: 0.0011
# Epoch 123/150
# 8/8 [==============================] - 1s 112ms/step - loss: 5.8036e-04 - val_loss: 9.0182e-04
# Epoch 124/150
# 8/8 [==============================] - 1s 108ms/step - loss: 6.0875e-04 - val_loss: 9.5480e-04
# Epoch 125/150
# 8/8 [==============================] - 1s 106ms/step - loss: 6.2647e-04 - val_loss: 8.8927e-04
# Epoch 126/150
# 8/8 [==============================] - 1s 107ms/step - loss: 6.1775e-04 - val_loss: 0.0010
# Epoch 127/150
# 8/8 [==============================] - 1s 104ms/step - loss: 5.0443e-04 - val_loss: 0.0010
# Epoch 128/150
# 8/8 [==============================] - 1s 104ms/step - loss: 5.0233e-04 - val_loss: 8.7788e-04
# Epoch 129/150
# 8/8 [==============================] - 1s 102ms/step - loss: 5.7257e-04 - val_loss: 0.0011
# Epoch 130/150
# 8/8 [==============================] - 1s 104ms/step - loss: 6.3664e-04 - val_loss: 8.6064e-04
# Epoch 131/150
# 8/8 [==============================] - 1s 107ms/step - loss: 5.6277e-04 - val_loss: 8.6817e-04
# Epoch 132/150
# 8/8 [==============================] - 1s 107ms/step - loss: 5.3430e-04 - val_loss: 0.0011
# Epoch 133/150
# 8/8 [==============================] - 1s 111ms/step - loss: 4.9882e-04 - val_loss: 8.7057e-04
# Epoch 134/150
# 8/8 [==============================] - 1s 103ms/step - loss: 4.8358e-04 - val_loss: 9.3696e-04
# Epoch 135/150
# 8/8 [==============================] - 1s 107ms/step - loss: 4.7729e-04 - val_loss: 9.5721e-04
# Epoch 136/150
# 8/8 [==============================] - 1s 103ms/step - loss: 5.2741e-04 - val_loss: 8.7062e-04
# Epoch 137/150
# 8/8 [==============================] - 1s 102ms/step - loss: 5.3480e-04 - val_loss: 8.5866e-04
# Epoch 138/150
# 8/8 [==============================] - 1s 103ms/step - loss: 5.2287e-04 - val_loss: 9.6823e-04
# Epoch 139/150
# 8/8 [==============================] - 1s 105ms/step - loss: 4.7880e-04 - val_loss: 9.8844e-04
# Epoch 140/150
# 8/8 [==============================] - 1s 110ms/step - loss: 6.5989e-04 - val_loss: 0.0012
# Epoch 141/150
# 8/8 [==============================] - 1s 106ms/step - loss: 4.8626e-04 - val_loss: 8.5316e-04
# Epoch 142/150
# 8/8 [==============================] - 1s 106ms/step - loss: 6.1367e-04 - val_loss: 0.0011
# Epoch 143/150
# 8/8 [==============================] - 1s 106ms/step - loss: 5.1301e-04 - val_loss: 8.2655e-04
# Epoch 144/150
# 8/8 [==============================] - 1s 107ms/step - loss: 5.2792e-04 - val_loss: 8.2825e-04
# Epoch 145/150
# 8/8 [==============================] - 1s 102ms/step - loss: 4.7804e-04 - val_loss: 0.0010
# Epoch 146/150
# 8/8 [==============================] - 1s 106ms/step - loss: 4.9426e-04 - val_loss: 9.5843e-04
# Epoch 147/150
# 8/8 [==============================] - 1s 104ms/step - loss: 4.8354e-04 - val_loss: 0.0017
# Epoch 148/150
# 8/8 [==============================] - 1s 105ms/step - loss: 6.1371e-04 - val_loss: 8.1179e-04
# Epoch 149/150
# 8/8 [==============================] - 1s 103ms/step - loss: 4.6900e-04 - val_loss: 0.0013
# Epoch 150/150
# 8/8 [==============================] - 1s 102ms/step - loss: 6.0817e-04 - val_loss: 8.7574e-04

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 15/15 [==============================] - 0s 20ms/step
# 3/3 [==============================] - 0s 20ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train, train_predict))
math.sqrt(mean_squared_error(y_test, test_predict))
# Out:
# 145.02844238895992

# %%
look_back = time_step
trainPredictPlot = np.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict) + look_back, :] = train_predict

testPredictPlot = np.empty_like(df)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict) + (look_back * 2) + 1:len(df) - 1, :] = test_predict

import matplotlib.pyplot as plt

plt.plot(scaler.inverse_transform(df))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
